# %%
import pandas as pd
import sys
import time

# %%
import pandas as pd
import sys
import time

# %%
import pandas as pd
import sys
import time

# %% [markdown]
# # Load Feature 1 euro exchange rate from CSV

# %%
df = pd.read_csv("./independendt projecct/euro_exchange_rate.csv")

# %%
# df 前7行去掉 9.30.2019
df = df.iloc[7:,]

# %%
df.head()
# Out:
#            Data Source in SDW: http://sdw.ecb.europa.eu/quickview.do;jsessionid=397A29BB2F1436B9AB6FAEE7A6C2F6BB?SERIES_KEY=120.EXR.D.E5.EUR.EN00.A&start=03-10-2014&end=10-10-2019&submitOptions.x=0&submitOptions.y=0&trans=N
# 2019-09-30                                            96.9520
# 2019-09-27                                            97.1966
# 2019-09-26                                            97.1416
# 2019-09-25                                            97.3576
# 2019-09-24                                            97.3220

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
# 取出exchange rate值
a=df.iloc[:,0:]
euro_byday=df.iloc[:,0:].values

print(type(df))
print(type(euro_byday))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
# 去除空值
for i in range(len(euro_byday)):
    if (euro_byday[i] == "-"):
        j = i
        while euro_byday[j] == "-":
            j = j - 1
        euro_byday[i] = euro_byday[j]

# %%
euro_byday_float = euro_byday.astype('float')

# %%
euro_byday_float = np.flip(euro_byday_float)
euro_byday_float
# Out:
# array([[98.3161],
#        [98.1501],
#        [98.2508],
#        ...,
#        [97.1416],
#        [97.1966],
#        [96.952 ]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(euro_byday_float)

# %% [markdown]
# # Load Feature 2 dj index from CSV

# %%
df = pd.read_csv("./independendt projecct/Dow jones industrial average.csv")

# %%
df = df.iloc[:-2,]
df.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 1251  2019-09-24  27034.070313  27079.679688  26704.960938  26807.769531
# 1252  2019-09-25  26866.710938  27016.560547  26755.859375  26970.710938
# 1253  2019-09-26  27004.109375  27015.070313  26803.839844  26891.119141
# 1254  2019-09-27  26987.259766  27012.539063  26715.820313  26820.250000
# 1255  2019-09-30  26852.330078  26998.859375  26852.330078  26916.830078
#
#          Adj Close     Volume
# 1251  26807.769531  301750000
# 1252  26970.710938  237220000
# 1253  26891.119141  229180000
# 1254  26820.250000  217780000
# 1255  26916.830078  222680000

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
d = df.values[:,1:-2]

# %%
dj_byday_float = d.astype('float')

# %%
dj_byday_float
# Out:
# array([[16802.199219, 17027.839844, 16802.199219, 17009.689453],
#        [17010.339844, 17099.390625, 16930.380859, 16991.910156],
#        [16988.25    , 16988.25    , 16715.789063, 16719.390625],
#        ...,
#        [27004.109375, 27015.070313, 26803.839844, 26891.119141],
#        [26987.259766, 27012.539063, 26715.820313, 26820.25    ],
#        [26852.330078, 26998.859375, 26852.330078, 26916.830078]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(dj_byday_float)
# Out:
# [<matplotlib.lines.Line2D at 0x7ff052a319d0>,
#  <matplotlib.lines.Line2D at 0x7ff052a31b90>,
#  <matplotlib.lines.Line2D at 0x7ff052a31d90>,
#  <matplotlib.lines.Line2D at 0x7ff052a31f50>]

# %% [markdown]
# # Load Feature 3 CPI.csv

# %%
df = pd.read_csv("./independendt projecct/CPI.csv")

# %%
df = df.iloc[:-2,1:-2]

# %% [markdown]
# ## Process Data

# %%
import numpy as np

# %%
CPI_byday = df.values[:,1:-2]

# %%
CPI_byday_float =CPI_byday.astype('float')

# %%
CPI_byday_float
# Out:
# array([[26.42    ],
#        [26.49    ],
#        [26.5     ],
#        ...,
#        [28.030001],
#        [27.99    ],
#        [27.950001]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(CPI_byday_float)

# %% [markdown]
# # Load Feature 4 GBBEF(exchange coe).csv

# %%
df = pd.read_csv("./independendt projecct/GBBEF(exchange coe).csv")

# %%
df = df.iloc[:-10,]
df.tail()
# Out:
#             Date  Open  High   Low  Close  Adj Close  Volume
# 1244  2019-09-26  31.9  31.9  31.9   31.9       31.9       0
# 1245  2019-09-27  31.9  31.9  31.9   31.9       31.9       0
# 1246  2019-09-30  31.9  31.9  31.9   31.9       31.9       0
# 1247  2019-10-01  31.9  31.9  31.9   31.9       31.9       0
# 1248  2019-10-02  31.9  31.9  31.9   31.9       31.9       0

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
GBBEF_byday = df.values[:,1:-2]

# %%
GBBEF_byday_float =GBBEF_byday.astype('float')

# %%
GBBEF_byday_float
# Out:
# array([[42.299999, 42.299999, 42.299999, 42.299999],
#        [42.299999, 42.299999, 42.299999, 42.299999],
#        [42.299999, 42.299999, 42.299999, 42.299999],
#        ...,
#        [31.9     , 31.9     , 31.9     , 31.9     ],
#        [31.9     , 31.9     , 31.9     , 31.9     ],
#        [31.9     , 31.9     , 31.9     , 31.9     ]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(GBBEF_byday_float)
# Out:
# [<matplotlib.lines.Line2D at 0x7ff0529a9e50>,
#  <matplotlib.lines.Line2D at 0x7ff0529a9fd0>,
#  <matplotlib.lines.Line2D at 0x7ff052934250>,
#  <matplotlib.lines.Line2D at 0x7ff052934410>]

# %% [markdown]
# # Load Feature 5 Oil Prices

# %%
df = pd.read_csv("./independendt projecct/Crude oil prices.csv")

# %%
# df = df.iloc[:-4,]
df.tail()
# Out:
#             DATE DCOILWTICO
# 1300  2019-09-24      57.22
# 1301  2019-09-25      56.38
# 1302  2019-09-26      56.24
# 1303  2019-09-27      55.95
# 1304  2019-09-30      54.09

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
oil_byday = df.values[:,1:]

# %%
# 去除空值
for i in range(len(oil_byday)):
    if (oil_byday[i] == "."):
        j = i
        while oil_byday[j] == ".":
            j = j - 1
        oil_byday[i] = oil_byday[j]

# %%
oil_byday_float = oil_byday.astype('float')

# %%
oil_byday_float
# Out:
# array([[91.17],
#        [90.74],
#        [91.02],
#        ...,
#        [56.24],
#        [55.95],
#        [54.09]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(oil_byday_float)

# %% [markdown]
# # Load Value1 SP

# %%
df = pd.read_csv("./independendt projecct/SP500.csv")

# %%
df = df.iloc[:,]
df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1254  2019-09-24  3002.429932  3007.979980  2957.729980  2966.600098
# 1255  2019-09-25  2968.350098  2989.820068  2952.860107  2984.870117
# 1256  2019-09-26  2985.729980  2987.280029  2963.709961  2977.620117
# 1257  2019-09-27  2985.469971  2987.310059  2945.530029  2961.790039
# 1258  2019-09-30  2967.070068  2983.850098  2967.070068  2976.739990
#
#         Adj Close      Volume
# 1254  2966.600098  3868160000
# 1255  2984.870117  3318870000
# 1256  2977.620117  3077240000
# 1257  2961.790039  3243650000
# 1258  2976.739990  3247610000

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
SP_byday = df.values[:,-2]

# %%
SP_byday_float = SP_byday.astype('float')

# %%
SP_byday_float = SP_byday_float.T

# %%
SP_byday_float.shape
# Out:
# (1259,)

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(SP_byday_float)

# %% [markdown]
# # Load Label WMT

# %%
df = pd.read_csv("./independendt projecct/WMT.csv")

# %%
df = df.iloc[:-3,]
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1254  2019-09-24  118.250000  119.860001  118.010002  118.400002  117.871300
# 1255  2019-09-25  118.470001  118.720001  117.809998  118.470001  117.940987
# 1256  2019-09-26  118.800003  119.550003  118.190002  118.300003  117.771744
# 1257  2019-09-27  119.209999  119.230003  117.750000  118.449997  117.921074
# 1258  2019-09-30  118.669998  119.440002  118.559998  118.680000  118.150047
#
#        Volume
# 1254  7273100
# 1255  4613600
# 1256  3986900
# 1257  3434700
# 1258  3401400

# %%
WMT_byday = df.values[:,1]
WMT_byday = df.values[:,4]
length = WMT_byday.shape[0]

# %%
WMT_byday.shape
# Out:
# (1259,)

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
WMT_byday = df.values[:,-2]

# %%
WMT_byday_float = WMT_byday.astype('float')

# %%
WMT_byday_float = WMT_byday_float.T

# %%
WMT_byday_float.shape
# Out:
# (1259,)

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(WMT_byday_float*400) # Magnify for comparison

# plt.plot(cpi_byday_float*10000-200000)
# plt.plot(euro_byday_float*500)
plt.show()

# %% [markdown]
# # Fit model

# %%
from sklearn import linear_model
length = 1200

# %%
feat1 = np.array(euro_byday_float)
feat1.shape
# Out:
# (1302, 1)

# %%
feat2 = np.array(CPI_byday_float)
feat2.shape
# Out:
# (1256, 1)

# %%
feat3 = np.array(dj_byday_float)
feat3.shape
# Out:
# (1256, 4)

# %%
feat4 = np.array(GBBEF_byday_float)
feat4.shape
# Out:
# (1249, 4)

# %%
feat5 = np.array(oil_byday_float)
feat5.shape
# Out:
# (1305, 1)

# %%
val1 = np.matrix(SP_byday_float).T
val1.shape
# Out:
# (1259, 1)

# %%
val2 = np.matrix(WMT_byday_float).T
val2.shape
# Out:
# (1259, 1)

# %%
# unify shape
feat1 = feat1[-length:,:]
feat2 = feat2[-length:,:]
feat3 = feat3[-length:,:]
feat4 = feat4[-length:,:]
feat5 = feat5[-length:,:]
# Add yesterday price as feature
#feat6 = val1[-length-1:-1,:]
feat7 = val2[-length-1:-1,:]

val1 = val1[-length:,:]
#val2 = val2[-length:,:]

# %% [markdown]
# ## Build data set

# %%
data = np.hstack((
    feat1,
    feat2,
    feat3, 
    feat4,
    feat5,
   # feat6,
    feat7,
    val1,
    #val2
))

# %%
data.shape
# Out:
# (1200, 13)

# %%
data = data.T

# %%
# Split train validation,and test
train_data = data[:,:1000]
test_data = data[:,1000:1050]

# %%
train_x = train_data[:-1,:].T
train_y = train_data[-1:,:].T

test_x = test_data[:-1,:].T
test_y = test_data[-1:,:].T

# %% [markdown]
# ## Linear Regression w/ Cross Validation

# %%
from sklearn.model_selection import KFold

# %%
# Compute MAE
def compute_error(y_hat, y):
    # mean absolute error
    return np.abs(y_hat - y).mean()

def compute_error_normalized(y_hat, y):
    sum_peaks = [];
    for i in range(len(y)):
        if (i == 0 or y[i-1] < y[i]):
            if (i == len(y)-1 or y[i] > y[i+1]):
                sum_peaks.append(y[i])
                
    return np.abs(y_hat - y).mean() / np.array(sum_peaks).mean()

# %%
KS = [4,5,6,8,10]  # Possible Splits for Cross Validation
ALPHAS = [10**-6, 10**-4, 10**-2, 1, 10]  # Model Smooth Constant

# %%
# Vars to store results
cval_errs = {} # Mean validation errors
train_time = {} # Training time
# Best Model
best_l_regressor = None
# Best Validation Error
best_err = sys.maxsize


for K in KS:
    for a in ALPHAS:
        for regor in [linear_model.Ridge, linear_model.Lasso]:
            kf = KFold(n_splits=K, random_state=None, shuffle=False)
            y_err = []

            start = time.time()

            # Cross Validaiton
            for train_index, val_index in kf.split(train_x):
            #     print("TRAIN:", train_index, "VAL:", val_index)
                X_train, X_val = train_x[train_index], train_x[val_index]
                y_train, y_val = train_y[train_index], train_y[val_index]

                LRegressor = regor(alpha=a)
                y_hat = LRegressor.fit(X_train, y_train).predict(X_val)
            #     print(y_hat)
                y_err.append(compute_error(y_hat, y_val))

            end = time.time()

            print(str(regor.__name__), str(a), "mean val MAE:", np.mean(y_err))
#             print("Time lapsed", str((end - start)*1000))

            # add to dict
            cval_errs[regor.__name__+str(a)] = np.mean(y_err)
            train_time[regor.__name__+str(a)] = (end - start)*1000
            if np.mean(y_err) < best_err:
                best_af_l_regressor = regor(alpha=a)
                best_k = K
                best_err = np.mean(y_err)
                best_errs = y_err
                
print(best_af_l_regressor, best_err)
# Out:
# Ridge 1e-06 mean val MAE: 22.463378970107698
# Lasso 1e-06 mean val MAE: 93.37144476517548
# Ridge 0.0001 mean val MAE: 22.46341261770356
# Lasso 0.0001 mean val MAE: 93.37139225271919
# Ridge 0.01 mean val MAE: 22.466780050466035
# Lasso 0.01 mean val MAE: 93.36633196509713
# Ridge 1 mean val MAE: 22.81406773496398
# Lasso 1 mean val MAE: 93.07959043295006
# Ridge 10 mean val MAE: 24.926003512394644
# Lasso 10 mean val MAE: 91.02203236340071
# Ridge 1e-06 mean val MAE: 21.751419790863427
# Lasso 1e-06 mean val MAE: 99.37400005771288
# Ridge 0.0001 mean val MAE: 21.751457720483558
# Lasso 0.0001 mean val MAE: 99.37405025016056
# Ridge 0.01 mean val MAE: 21.75524914367724
# Lasso 0.01 mean val MAE: 99.3791957450956
# Ridge 1 mean val MAE: 22.121490927437186
# Lasso 1 mean val MAE: 99.57725988350455
# Ridge 10 mean val MAE: 24.185127010163235
# Lasso 10 mean val MAE: 98.79892669919248
# /home/will/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Ridge 1e-06 mean val MAE: 20.339071014791614
# Lasso 1e-06 mean val MAE: 76.90078283083322
# Ridge 0.0001 mean val MAE: 20.339087203758126
# Lasso 0.0001 mean val MAE: 76.90076224258353
# Ridge 0.01 mean val MAE: 20.34071383172939
# Lasso 0.01 mean val MAE: 76.89878152681302
# Ridge 1 mean val MAE: 20.548148041812762
# Lasso 1 mean val MAE: 77.19705840603233
# Ridge 10 mean val MAE: 22.268257502169202
# Lasso 10 mean val MAE: 77.32982899742423
# Ridge 1e-06 mean val MAE: 21.56908355996362
# Lasso 1e-06 mean val MAE: 67.91077064640436
# Ridge 0.0001 mean val MAE: 21.56908533705279
# Lasso 0.0001 mean val MAE: 67.91064482637549
# Ridge 0.01 mean val MAE: 21.569271631001243
# Lasso 0.01 mean val MAE: 67.89640281273472
# Ridge 1 mean val MAE: 21.62436453187545
# Lasso 1 mean val MAE: 67.3398618846918
# Ridge 10 mean val MAE: 22.33409138999243
# Lasso 10 mean val MAE: 67.36747662861363
# Ridge 1e-06 mean val MAE: 18.644841247859098
# Lasso 1e-06 mean val MAE: 65.31945000732493
# Ridge 0.0001 mean val MAE: 18.64485027752013
# Lasso 0.0001 mean val MAE: 65.31936347461185
# Ridge 0.01 mean val MAE: 18.645753491288733
# Lasso 0.01 mean val MAE: 65.31226028643296
# Ridge 1 mean val MAE: 18.738401649661252
# Lasso 1 mean val MAE: 64.8268420080681
# Ridge 10 mean val MAE: 19.42901624454865
# Lasso 10 mean val MAE: 65.06000109859596
# Ridge(alpha=1e-06, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001) 18.644841247859098

# %% [markdown]
# # Test

# %%
best_af_l_regressor = best_af_l_regressor.fit(train_x, train_y)

# %%
y_hat = best_af_l_regressor.predict(test_x)

# %%
plt.plot(y_hat[:,0], label="estmated SP")
plt.plot(test_y[:,0], label="real SP")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# # Test Error

# %%
compute_error(y_hat, test_y)
# Out:
# 10.211167793397017

# %%
compute_error_normalized(y_hat, test_y)*100
# Out:
# 0.3846776877909993

# %% [markdown]
# # Fit model

# %%
from sklearn import linear_model
length = 1200

# %%
feat1 = np.array(euro_byday_float)
feat1.shape
# Out:
# (1302, 1)

# %%
feat2 = np.array(CPI_byday_float)
feat2.shape
# Out:
# (1256, 1)

# %%
feat3 = np.array(dj_byday_float)
feat3.shape
# Out:
# (1256, 4)

# %%
feat4 = np.array(GBBEF_byday_float)
feat4.shape
# Out:
# (1249, 4)

# %%
feat5 = np.array(oil_byday_float)
feat5.shape
# Out:
# (1305, 1)

# %%
val1 = np.matrix(SP_byday_float).T
val1.shape
# Out:
# (1259, 1)

# %%
val2 = np.matrix(WMT_byday_float).T
val2.shape
# Out:
# (1259, 1)

# %%
# unify shape
feat1 = feat1[-length:,:]
feat2 = feat2[-length:,:]
feat3 = feat3[-length:,:]
feat4 = feat4[-length:,:]
feat5 = feat5[-length:,:]
# Add yesterday price as feature
feat6 = val1[-length-1:-1,:]
# feat7 = val2[-length-1:-1,:]

#val1 = val1[-length:,:]
val2 = val2[-length:,:]

# %% [markdown]
# ## Build data set

# %%
data = np.hstack((
    feat1,
    feat2,
    feat3, 
    feat4,
    feat5,
    feat6,
#     feat7,
  #  val1,
    val2))

# %%
data.shape
# Out:
# (1200, 13)

# %%
data = data.T

# %%
# Split train validation,and test
train_data = data[:,:1000]
test_data = data[:,1000:1050]

# %%
train_x = train_data[:-1,:].T
train_y = train_data[-1:,:].T

test_x = test_data[:-1,:].T
test_y = test_data[-1:,:].T

# %% [markdown]
# ## Linear Regression w/ Cross Validation

# %%
from sklearn.model_selection import KFold

# %%
# Compute MAE
def compute_error(y_hat, y):
    # mean absolute error
    return np.abs(y_hat - y).mean()

def compute_error_normalized(y_hat, y):
    sum_peaks = [];
    for i in range(len(y)):
        if (i == 0 or y[i-1] < y[i]):
            if (i == len(y)-1 or y[i] > y[i+1]):
                sum_peaks.append(y[i])
                
    return np.abs(y_hat - y).mean() / np.array(sum_peaks).mean()

# %%
KS = [4,5,6,8,10]  # Possible Splits for Cross Validation
ALPHAS = [10**-6, 10**-4, 10**-2, 1, 10]  # Model Smooth Constant

# %%
# Vars to store results
cval_errs = {} # Mean validation errors
train_time = {} # Training time
# Best Model
best_l_regressor = None
# Best Validation Error
best_err = sys.maxsize


for K in KS:
    for a in ALPHAS:
        for regor in [linear_model.Ridge, linear_model.Lasso]:
            kf = KFold(n_splits=K, random_state=None, shuffle=False)
            y_err = []

            start = time.time()

            # Cross Validaiton
            for train_index, val_index in kf.split(train_x):
            #     print("TRAIN:", train_index, "VAL:", val_index)
                X_train, X_val = train_x[train_index], train_x[val_index]
                y_train, y_val = train_y[train_index], train_y[val_index]

                LRegressor = regor(alpha=a)
                y_hat = LRegressor.fit(X_train, y_train).predict(X_val)
            #     print(y_hat)
                y_err.append(compute_error(y_hat, y_val))

            end = time.time()

            print(str(regor.__name__), str(a), "mean val MAE:", np.mean(y_err))
#             print("Time lapsed", str((end - start)*1000))

            # add to dict
            cval_errs[regor.__name__+str(a)] = np.mean(y_err)
            train_time[regor.__name__+str(a)] = (end - start)*1000
            if np.mean(y_err) < best_err:
                best_af_l_regressor = regor(alpha=a)
                best_k = K
                best_err = np.mean(y_err)
                best_errs = y_err
                
print(best_af_l_regressor, best_err)
# Out:
# Ridge 1e-06 mean val MAE: 6.4224466653374215
# Lasso 1e-06 mean val MAE: 7.158657776188657
# Ridge 0.0001 mean val MAE: 6.422445135533822
# Lasso 0.0001 mean val MAE: 7.158542462395328
# Ridge 0.01 mean val MAE: 6.422294635898644
# Lasso 0.01 mean val MAE: 7.144360030589869
# Ridge 1 mean val MAE: 6.416925316472168
# Lasso 1 mean val MAE: 6.559472119805127
# Ridge 10 mean val MAE: 6.409545788657806
# Lasso 10 mean val MAE: 6.316517619981601
# Ridge 1e-06 mean val MAE: 7.651515641888373
# Lasso 1e-06 mean val MAE: 8.595406154170664
# Ridge 0.0001 mean val MAE: 7.651515534437719
# Lasso 0.0001 mean val MAE: 8.595709497921396
# Ridge 0.01 mean val MAE: 7.651506723584163
# Lasso 0.01 mean val MAE: 8.62388728142141
# Ridge 1 mean val MAE: 7.659371577724912
# Lasso 1 mean val MAE: 7.803163911874222
# Ridge 10 mean val MAE: 7.726051294000055
# /home/will/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Lasso 10 mean val MAE: 7.009410312568724
# Ridge 1e-06 mean val MAE: 7.014438854550854
# Lasso 1e-06 mean val MAE: 7.526735482769987
# Ridge 0.0001 mean val MAE: 7.014438046576296
# Lasso 0.0001 mean val MAE: 7.526925557003075
# Ridge 0.01 mean val MAE: 7.014359069362996
# Lasso 0.01 mean val MAE: 7.531400314031761
# Ridge 1 mean val MAE: 7.0132295004650205
# Lasso 1 mean val MAE: 6.865575851623504
# Ridge 10 mean val MAE: 7.014996661332194
# Lasso 10 mean val MAE: 6.371443823785526
# Ridge 1e-06 mean val MAE: 6.439929563734035
# Lasso 1e-06 mean val MAE: 7.30029014257158
# Ridge 0.0001 mean val MAE: 6.4399278168881615
# Lasso 0.0001 mean val MAE: 7.300136268695985
# Ridge 0.01 mean val MAE: 6.439755054296253
# Lasso 0.01 mean val MAE: 7.288588421145484
# Ridge 1 mean val MAE: 6.430941393724714
# Lasso 1 mean val MAE: 6.539689938967838
# Ridge 10 mean val MAE: 6.405110965098893
# Lasso 10 mean val MAE: 5.876826410969197
# Ridge 1e-06 mean val MAE: 6.291085034534423
# Lasso 1e-06 mean val MAE: 6.74694983187454
# Ridge 0.0001 mean val MAE: 6.291084922868628
# Lasso 0.0001 mean val MAE: 6.747128578865073
# Ridge 0.01 mean val MAE: 6.291074101335476
# Lasso 0.01 mean val MAE: 6.759596161304119
# Ridge 1 mean val MAE: 6.291821481012571
# Lasso 1 mean val MAE: 6.31202894274334
# Ridge 10 mean val MAE: 6.301995967397036
# Lasso 10 mean val MAE: 5.79202300479337
# Lasso(alpha=10, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False) 5.79202300479337

# %% [markdown]
# # Test

# %%
best_af_l_regressor = best_af_l_regressor.fit(train_x, train_y)
# Out:
# /home/will/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
y_hat = best_af_l_regressor.predict(test_x)

# %%
plt.plot(y_hat[:], label="estmated WMT")
plt.plot(test_y[:], label="real WMT")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# # Test Error

# %%
compute_error(y_hat, test_y)
# Out:
# 4.324902443413354
