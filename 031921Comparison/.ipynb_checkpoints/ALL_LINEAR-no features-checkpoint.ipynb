# %%
import dataloader
import utils
import linear

import datetime
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (20,10)

# %load_ext autoreload
# %autoreload 2

# Model Data range
date = datetime.datetime(2021,3,12)
# Total entry count
count = 180
training_count = 150

history_size = 1

# %%
path = "./Data/BTC-USD-2.csv"
# Load data, with open price.
train_x, train_y, test_x, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x = np.resize(train_x, (training_count - history_size, history_size))
test_x = np.resize(test_x, (count - training_count, history_size))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1812, 8)
# (1290, 8)
# (1288, 8)
# (1288, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 1)
# (30, 1)

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 2)
# (30, 2)

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 3)
# (30, 3)

# %%
path = "./Data/GBBEF-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 4)
# (30, 4)

# %%
path = "./Data/GBBEF-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 5)
# (30, 5)

# %%
path = "./Data/GC=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 6)
# (30, 6)

# %%
path = "./Data/GC=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 7)
# (30, 7)

# %%
# AMZN

# %%
path = "./Data/AMZN2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 7)
# (30, 7)

# %%
path = "./Data/AMZN2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)

# %%
ALPHAS = [10**-6, 10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1]  # Model Smooth Constant
regressor, best_err = linear.linear_regression_model_selection(train_x1, train_y, ALPHAS)
# Out:
# 1e-06 mean val RMSE: 0.21356953360691314
# Time lapsed 24.379730224609375
# 1e-05 mean val RMSE: 0.21339546970927023
# Time lapsed 3.914356231689453
# 0.0001 mean val RMSE: 0.2119847622778824
# Time lapsed 3.689289093017578
# 0.001 mean val RMSE: 0.20699505191241693
# Time lapsed 3.7147998809814453
# 0.01 mean val RMSE: 0.1942560001965968
# Time lapsed 3.6859512329101562
# 0.1 mean val RMSE: 0.18039654219777762
# Time lapsed 3.673076629638672
# 1 mean val RMSE: 0.1719430315339826
# Time lapsed 4.369974136352539
# 1e-06 mean val RMSE: 0.2132421317043971
# Time lapsed 4.073858261108398
# 1e-05 mean val RMSE: 0.20844430633411357
# Time lapsed 4.458904266357422
# 0.0001 mean val RMSE: 0.19687415098097277
# Time lapsed 4.33039665222168
# 0.001 mean val RMSE: 0.16957067061260023
# Time lapsed 4.268884658813477
# 0.01 mean val RMSE: 0.1714532999079064
# Time lapsed 3.8459300994873047
# 0.1 mean val RMSE: 0.16942635893516536
# Time lapsed 3.8270950317382812
# 1 mean val RMSE: 0.16942635893516536
# Time lapsed 3.868579864501953

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.13444434670004227
# RMSE:  0.15222044160903533

# %% [markdown]
# # SONY

# %%
path = "./Data/SONY2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 7)
# (30, 7)

# %%
path = "./Data/SONY2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)

# %%
ALPHAS = [10**-6, 10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1]  # Model Smooth Constant
regressor, best_err = linear.linear_regression_model_selection(train_x1, train_y, ALPHAS)
# Out:
# 1e-06 mean val RMSE: 0.19524091161823146
# Time lapsed 4.332304000854492
# 1e-05 mean val RMSE: 0.19511485766226483
# Time lapsed 3.9734840393066406
# 0.0001 mean val RMSE: 0.19414363260493106
# Time lapsed 3.6842823028564453
# 0.001 mean val RMSE: 0.1909634616040096
# Time lapsed 3.710508346557617
# 0.01 mean val RMSE: 0.18093927118220968
# Time lapsed 4.180669784545898
# 0.1 mean val RMSE: 0.1487195960690325
# Time lapsed 3.7283897399902344
# 1 mean val RMSE: 0.09866156176935292
# Time lapsed 3.7195682525634766
# 1e-06 mean val RMSE: 0.19434168163158466
# Time lapsed 3.991842269897461
# 1e-05 mean val RMSE: 0.189818900877056
# Time lapsed 4.462003707885742
# 0.0001 mean val RMSE: 0.1807678223547486
# Time lapsed 4.453182220458984
# 0.001 mean val RMSE: 0.13643015449848875
# Time lapsed 4.297971725463867
# 0.01 mean val RMSE: 0.17610188454575385
# Time lapsed 4.768848419189453
# 0.1 mean val RMSE: 0.2409729790651846
# Time lapsed 4.150390625
# 1 mean val RMSE: 0.2409729790651846
# Time lapsed 4.344463348388672

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.2596170657708831
# RMSE:  0.3009492879335482

# %%
# IBIO

# %%
path = "./Data/IBIO2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)
# (149, 7)
# (30, 7)

# %%
path = "./Data/IBIO2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (149, 1, 1)
# (30, 1, 1)

# %%
ALPHAS = [10**-6, 10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1]  # Model Smooth Constant
regressor, best_err = linear.linear_regression_model_selection(train_x1, train_y, ALPHAS)
# Out:
# 1e-06 mean val RMSE: 0.1808397205800118
# Time lapsed 4.359006881713867
# 1e-05 mean val RMSE: 0.18013784957684162
# Time lapsed 4.447698593139648
# 0.0001 mean val RMSE: 0.17456675145848127
# Time lapsed 3.713369369506836
# 0.001 mean val RMSE: 0.1597548033543039
# Time lapsed 3.7021636962890625
# 0.01 mean val RMSE: 0.15282762779733833
# Time lapsed 3.7088394165039062
# 0.1 mean val RMSE: 0.16543190462057117
# Time lapsed 3.7012100219726562
# 1 mean val RMSE: 0.16166672980399882
# Time lapsed 4.204034805297852
# 1e-06 mean val RMSE: 0.18006964030434708
# Time lapsed 4.450082778930664
# 1e-05 mean val RMSE: 0.1733292752621222
# Time lapsed 4.372119903564453
# 0.0001 mean val RMSE: 0.15914608689577753
# Time lapsed 4.335165023803711
# 0.001 mean val RMSE: 0.16176882376400897
# Time lapsed 4.82940673828125
# 0.01 mean val RMSE: 0.1881168731989234
# Time lapsed 4.109859466552734
# 0.1 mean val RMSE: 0.188434940217523
# Time lapsed 4.282951354980469
# 1 mean val RMSE: 0.188434940217523
# Time lapsed 4.329919815063477

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   3.6629160723631906
# RMSE:  3.708482871624175

# %%
plt.plot(train_y[:])
