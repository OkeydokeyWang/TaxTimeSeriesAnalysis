# %%
import dataloader
import utils
import knn

import datetime
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (20,10)

# %load_ext autoreload
# %autoreload 2

# Model Data range
date = datetime.datetime(2021,3,12)
# Total entry count
count = 1200
training_count = 1000

history_size = 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x, train_y, test_x, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x = np.resize(train_x, (training_count - history_size, history_size))
test_x = np.resize(test_x, (count - training_count, history_size))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 1)
# (200, 1)

# %%
path = "./Data/SPY-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 2)
# (200, 2)

# %%
path = "./Data/YM=F.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 3)
# (200, 3)

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 4)
# (200, 4)

# %%
path = "./Data/GBBEF-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 5)
# (200, 5)

# %%
path = "./Data/GBBEF-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 6)
# (200, 6)

# %%
path = "./Data/GC=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 7)
# (200, 7)

# %%
path = "./Data/GC=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 8)
# (200, 8)

# %% [markdown]
# # AMZN

# %%
path = "./Data/AMZN2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x1.shape)
print(test_x1.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 9)
# (200, 9)

# %%
path = "./Data/AMZN2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)

# %%
nn_params = [3, 5, 10, 20, 25]
regressor, best_err = knn.knn_model_selection(train_x1, train_y, nn_params)
# Out:
# 3 mean val RMSE: 0.15289155731315898
# Time lapsed 10.838985443115234
# 5 mean val RMSE: 0.14977585790145104
# Time lapsed 10.657548904418945
# 10 mean val RMSE: 0.14511039231946574
# Time lapsed 12.697696685791016
# 20 mean val RMSE: 0.1429973034375336
# Time lapsed 16.490459442138672
# 25 mean val RMSE: 0.1429273560621856
# Time lapsed 16.421794891357422

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.7421300692049273
# RMSE:  0.7493506868807768

# %% [markdown]
# # SONY

# %%
path = "./Data/SONY2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x1.shape)
print(test_x1.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 9)
# (200, 9)

# %%
path = "./Data/SONY2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)

# %%
nn_params = [3, 5, 10, 20, 25]
regressor, best_err = knn.knn_model_selection(train_x1, train_y, nn_params)
# Out:
# 3 mean val RMSE: 0.10631691701797244
# Time lapsed 9.73367691040039
# 5 mean val RMSE: 0.10396725837535395
# Time lapsed 10.749340057373047
# 10 mean val RMSE: 0.10130568329742233
# Time lapsed 12.824535369873047
# 20 mean val RMSE: 0.10044296865556504
# Time lapsed 13.789653778076172
# 25 mean val RMSE: 0.10094354109668535
# Time lapsed 13.812541961669922

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.548242294344006
# RMSE:  0.5643832726101201

# %% [markdown]
# # IBIO

# %%
path = "./Data/IBIO2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x1.shape)
print(test_x1.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 9)
# (200, 9)

# %%
path = "./Data/IBIO2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)

# %%
nn_params = [3, 5, 10, 20, 25]
regressor, best_err = knn.knn_model_selection(train_x1, train_y, nn_params)
# Out:
# 3 mean val RMSE: 0.2921813149204272
# Time lapsed 11.641502380371094
# 5 mean val RMSE: 0.2864114129383289
# Time lapsed 11.672258377075195
# 10 mean val RMSE: 0.2795580596836057
# Time lapsed 12.676239013671875
# 20 mean val RMSE: 0.2712393952572465
# Time lapsed 14.987945556640625
# 25 mean val RMSE: 0.27021287288527196
# Time lapsed 16.092538833618164

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.32523347050754464
# RMSE:  0.36127732821966757
