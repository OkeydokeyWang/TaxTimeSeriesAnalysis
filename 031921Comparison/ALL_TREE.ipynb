# %%
import dataloader
import utils
import dtree

import datetime
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (20,10)

# %load_ext autoreload
# %autoreload 2

# Model Data range
date = datetime.datetime(2021,3,12)
# Total entry count
count = 1200
training_count = 1000

history_size = 1

# %%
path = "./Data/BTC-USD-2.csv"
# Load data, with open price.
train_x, train_y, test_x, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x = np.resize(train_x, (training_count - history_size, history_size))
test_x = np.resize(test_x, (count - training_count, history_size))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1812, 8)
# (1290, 8)
# (1288, 8)
# (1288, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 1)
# (200, 1)

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 2)
# (200, 2)

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 3)
# (200, 3)

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 4)
# (200, 4)

# %%
path = "./Data/GBBEF-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 5)
# (200, 5)

# %%
path = "./Data/GBBEF-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 6)
# (200, 6)

# %%
path = "./Data/GC=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 7)
# (200, 7)

# %%
path = "./Data/GC=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 8)
# (200, 8)

# %%
# AMZN

# %%
path = "./Data/AMZN2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 8)
# (200, 8)

# %%
path = "./Data/AMZN2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)

# %%
criteria_params = ["mse", "mae"]
max_depth_params = [6, 9, 12, 15, 19, 25, 30, 50]
regressor, best_err = dtree.dicision_tree_model_selection(train_x1, train_y, criteria_params, max_depth_params)
# Out:
# mse 6 mean val MSE: 0.06927024590746673
# mse 9 mean val MSE: 0.07117725808808478
# mse 12 mean val MSE: 0.07371043862466764
# mse 15 mean val MSE: 0.07737995231936233
# mse 19 mean val MSE: 0.07455945811295746
# mse 25 mean val MSE: 0.07506460881355444
# mse 30 mean val MSE: 0.07588429291152718
# mse 50 mean val MSE: 0.07379108540211105
# mae 6 mean val MSE: 0.0692219143659257
# mae 9 mean val MSE: 0.08053019912593222
# mae 12 mean val MSE: 0.0771085374320402
# mae 15 mean val MSE: 0.08601982219049288
# mae 19 mean val MSE: 0.08725366359098682
# mae 25 mean val MSE: 0.08192822330706236
# mae 30 mean val MSE: 0.08486220544223769
# mae 50 mean val MSE: 0.08465479770753026

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.2387268582462926
# RMSE:  0.2534620288133321

# %%
# SONY

# %%
path = "./Data/SONY2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 8)
# (200, 8)

# %%
path = "./Data/SONY2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)

# %%
criteria_params = ["mse", "mae"]
max_depth_params = [6, 9, 12, 15, 19, 25, 30, 50]
regressor, best_err = dtree.dicision_tree_model_selection(train_x1, train_y, criteria_params, max_depth_params)
# Out:
# mse 6 mean val MSE: 0.08569156441395434
# mse 9 mean val MSE: 0.08277071047358422
# mse 12 mean val MSE: 0.08638166218002288
# mse 15 mean val MSE: 0.08622329234838982
# mse 19 mean val MSE: 0.08870919210072706
# mse 25 mean val MSE: 0.08818854062190759
# mse 30 mean val MSE: 0.08578649591641127
# mse 50 mean val MSE: 0.08614631037528746
# mae 6 mean val MSE: 0.09419775625488339
# mae 9 mean val MSE: 0.09861540873922496
# mae 12 mean val MSE: 0.10135196837574671
# mae 15 mean val MSE: 0.09867762277396856
# mae 19 mean val MSE: 0.10080450238501441
# mae 25 mean val MSE: 0.10038520261271353
# mae 30 mean val MSE: 0.09849955674751895
# mae 50 mean val MSE: 0.0992910984113693

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.3072155435313971
# RMSE:  0.34618367762584795

# %%
# IBIO

# %%
path = "./Data/IBIO2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)
# (999, 8)
# (200, 8)

# %%
path = "./Data/IBIO2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1200, 8)
# (999, 1, 1)
# (200, 1, 1)

# %%
criteria_params = ["mse", "mae"]
max_depth_params = [6, 9, 12, 15, 19, 25, 30, 50]
regressor, best_err = dtree.dicision_tree_model_selection(train_x1, train_y, criteria_params, max_depth_params)
# Out:
# mse 6 mean val MSE: 0.11933037593849254
# mse 9 mean val MSE: 0.12485341947185116
# mse 12 mean val MSE: 0.1225514221951353
# mse 15 mean val MSE: 0.12057237426930187
# mse 19 mean val MSE: 0.11900339812145473
# mse 25 mean val MSE: 0.12596727976478375
# mse 30 mean val MSE: 0.12719805773219411
# mse 50 mean val MSE: 0.12111718004983427
# mae 6 mean val MSE: 0.12857794788343804
# mae 9 mean val MSE: 0.12768778353168225
# mae 12 mean val MSE: 0.12660346331994557
# mae 15 mean val MSE: 0.12347915945278758
# mae 19 mean val MSE: 0.1271281024660516
# mae 25 mean val MSE: 0.12085853461947704
# mae 30 mean val MSE: 0.12390039467478335
# mae 50 mean val MSE: 0.12941610533695197

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.11126886145404664
# RMSE:  0.13972151312674874
