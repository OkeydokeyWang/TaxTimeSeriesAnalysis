# %%
import dataloader
import utils
import linear

import datetime
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (20,10)

# %load_ext autoreload
# %autoreload 2

# Model Data range
date = datetime.datetime(2021,3,12)
# Total entry count
count = 540
training_count = 450

history_size = 1

# %%
path = "./Data/BTC-USD-2.csv"
# Load data, with open price.
train_x, train_y, test_x, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x = np.resize(train_x, (training_count - history_size, history_size))
test_x = np.resize(test_x, (count - training_count, history_size))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1812, 8)
# (1290, 8)
# (1288, 8)
# (1288, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 1)
# (90, 1)

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 2)
# (90, 2)

# %%
path = "./Data/CL=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 3)
# (90, 3)

# %%
path = "./Data/GBBEF-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 4)
# (90, 4)

# %%
path = "./Data/GBBEF-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 5)
# (90, 5)

# %%
path = "./Data/GC=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 6)
# (90, 6)

# %%
path = "./Data/GC=F-2.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count, column="Volume"
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x = np.hstack((train_x, train_x0))
test_x = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1241, 8)
# (1241, 8)
# (1240, 8)
# (1240, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 7)
# (90, 7)

# %%
# AMZN

# %%
path = "./Data/AMZN2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 7)
# (90, 7)

# %%
path = "./Data/AMZN2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)

# %%
ALPHAS = [10**-6, 10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1]  # Model Smooth Constant
regressor, best_err = linear.linear_regression_model_selection(train_x1, train_y, ALPHAS)
# Out:
# 1e-06 mean val RMSE: 0.25812375198669496
# Time lapsed 30.36785125732422
# 1e-05 mean val RMSE: 0.2581236113253962
# Time lapsed 3.9758682250976562
# 0.0001 mean val RMSE: 0.2581222148368621
# Time lapsed 3.9315223693847656
# 0.001 mean val RMSE: 0.2581090962578335
# Time lapsed 3.9162635803222656
# 0.01 mean val RMSE: 0.2579764298741968
# Time lapsed 3.917694091796875
# 0.1 mean val RMSE: 0.2535403367738286
# Time lapsed 3.905057907104492
# 1 mean val RMSE: 0.22691216274132353
# Time lapsed 3.9005279541015625
# 1e-06 mean val RMSE: 0.25817065434204445
# Time lapsed 4.307270050048828
# 1e-05 mean val RMSE: 0.2587958779738922
# Time lapsed 4.8046112060546875
# 0.0001 mean val RMSE: 0.2659351460371997
# Time lapsed 4.741668701171875
# 0.001 mean val RMSE: 0.29275220933219825
# Time lapsed 4.694223403930664
# 0.01 mean val RMSE: 0.2906602668895097
# Time lapsed 4.59742546081543
# 0.1 mean val RMSE: 0.290136150703251
# Time lapsed 4.5909881591796875
# 1 mean val RMSE: 0.290136150703251
# Time lapsed 4.616022109985352

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.8994332803527728
# RMSE:  1.0201806827933242

# %% [markdown]
# # SONY

# %%
path = "./Data/SONY2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 7)
# (90, 7)

# %%
path = "./Data/SONY2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)

# %%
ALPHAS = [10**-6, 10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1]  # Model Smooth Constant
regressor, best_err = linear.linear_regression_model_selection(train_x1, train_y, ALPHAS)
# Out:
# 1e-06 mean val RMSE: 0.13750789797759894
# Time lapsed 7.375001907348633
# 1e-05 mean val RMSE: 0.13750524686837423
# Time lapsed 4.848957061767578
# 0.0001 mean val RMSE: 0.13747875972712623
# Time lapsed 4.6977996826171875
# 0.001 mean val RMSE: 0.13721620341400295
# Time lapsed 4.703521728515625
# 0.01 mean val RMSE: 0.1347693869167495
# Time lapsed 4.703283309936523
# 0.1 mean val RMSE: 0.11858889677282536
# Time lapsed 4.836797714233398
# 1 mean val RMSE: 0.12011129593373589
# Time lapsed 4.71949577331543
# 1e-06 mean val RMSE: 0.13746635832942042
# Time lapsed 5.692958831787109
# 1e-05 mean val RMSE: 0.1373221166077677
# Time lapsed 5.616188049316406
# 0.0001 mean val RMSE: 0.1351824217368203
# Time lapsed 5.575895309448242
# 0.001 mean val RMSE: 0.16041182311466895
# Time lapsed 5.530357360839844
# 0.01 mean val RMSE: 0.15588187288415792
# Time lapsed 5.44428825378418
# 0.1 mean val RMSE: 0.15588187288415792
# Time lapsed 5.412578582763672
# 1 mean val RMSE: 0.15588187288415792
# Time lapsed 5.504131317138672

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.6539108755837255
# RMSE:  0.7122475881777147

# %%
# IBIO

# %%
path = "./Data/IBIO2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x, (training_count - history_size, history_size))
test_x0 = np.resize(test_x, (count - training_count, history_size))
train_x1 = np.hstack((train_x, train_x0))
test_x1 = np.hstack((test_x, test_x0))
print(train_x.shape)
print(test_x.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)
# (449, 7)
# (90, 7)

# %%
path = "./Data/IBIO2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (540, 8)
# (449, 1, 1)
# (90, 1, 1)

# %%
ALPHAS = [10**-6, 10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1]  # Model Smooth Constant
regressor, best_err = linear.linear_regression_model_selection(train_x1, train_y, ALPHAS)
# Out:
# 1e-06 mean val RMSE: 0.16086652333786172
# Time lapsed 6.961822509765625
# 1e-05 mean val RMSE: 0.16086685465472902
# Time lapsed 4.614353179931641
# 0.0001 mean val RMSE: 0.16087017414186788
# Time lapsed 4.563570022583008
# 0.001 mean val RMSE: 0.16090385456508471
# Time lapsed 4.502534866333008
# 0.01 mean val RMSE: 0.16121937508232376
# Time lapsed 4.516124725341797
# 0.1 mean val RMSE: 0.16129427279523728
# Time lapsed 4.527807235717773
# 1 mean val RMSE: 0.14794775221633852
# Time lapsed 4.541873931884766
# 1e-06 mean val RMSE: 0.16091170694144566
# Time lapsed 4.2934417724609375
# 1e-05 mean val RMSE: 0.16133290202286277
# Time lapsed 4.779815673828125
# 0.0001 mean val RMSE: 0.16608885130229617
# Time lapsed 4.817962646484375
# 0.001 mean val RMSE: 0.16113066760981556
# Time lapsed 4.897832870483398
# 0.01 mean val RMSE: 0.14637519339969124
# Time lapsed 4.585981369018555
# 0.1 mean val RMSE: 0.14637519339969124
# Time lapsed 3.9975643157958984
# 1 mean val RMSE: 0.14637519339969124
# Time lapsed 4.651546478271484

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.07906930156373364
# RMSE:  0.09739017785522333

# %%
plt.plot(train_y[:])
