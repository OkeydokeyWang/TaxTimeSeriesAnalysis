# %%
import dataloader
import utils
import knn

import datetime
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (20,10)

# %load_ext autoreload
# %autoreload 2

# Model Data range
date = datetime.datetime(2021,3,12)
# Total entry count
count = 180
training_count = 150

history_size = 60
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # AMZN

# %%
path = "./Data/AMZN2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x0, (training_count - history_size, history_size))
test_x0 = np.resize(test_x0, (count - training_count, history_size))
train_x1 = np.hstack((train_x0, train_x0))
test_x1 = np.hstack((test_x0, test_x0))
print(train_x1.shape)
print(test_x1.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1242, 8)
# (1242, 8)
# (180, 8)
# (90, 60, 1)
# (30, 60, 1)
# (90, 120)
# (30, 120)

# %%
path = "./Data/AMZN2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (90, 60, 1)
# (30, 60, 1)

# %%
nn_params = [3, 5, 10, 20, 25]
regressor, best_err = knn.knn_model_selection(train_x1, train_y, nn_params)
# Out:
# 3 mean val RMSE: 0.12834557546523737
# Time lapsed 9.755849838256836
# 5 mean val RMSE: 0.12600778479457422
# Time lapsed 9.439229965209961
# 10 mean val RMSE: 0.11659316643403805
# Time lapsed 9.396076202392578
# 20 mean val RMSE: 0.1071306438502796
# Time lapsed 9.223461151123047
# 25 mean val RMSE: 0.10565331405805889
# Time lapsed 9.511232376098633

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.1281277193670863
# RMSE:  0.14753337877713454

# %% [markdown]
# # SONY

# %%
path = "./Data/SONY2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x0, (training_count - history_size, history_size))
test_x0 = np.resize(test_x0, (count - training_count, history_size))
train_x1 = np.hstack((train_x0, train_x0))
test_x1 = np.hstack((test_x0, test_x0))
print(train_x1.shape)
print(test_x1.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (90, 60, 1)
# (30, 60, 1)
# (90, 120)
# (30, 120)

# %%
path = "./Data/SONY2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (90, 60, 1)
# (30, 60, 1)

# %%
nn_params = [3, 5, 10, 20, 25]
regressor, best_err = knn.knn_model_selection(train_x1, train_y, nn_params)
# Out:
# 3 mean val RMSE: 0.05254394367488494
# Time lapsed 9.222745895385742
# 5 mean val RMSE: 0.05719621974202714
# Time lapsed 8.667469024658203
# 10 mean val RMSE: 0.07154968714279257
# Time lapsed 9.421110153198242
# 20 mean val RMSE: 0.09649240379500339
# Time lapsed 9.936809539794922
# 25 mean val RMSE: 0.11720480491187375
# Time lapsed 10.126590728759766

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.2116343476868288
# RMSE:  0.24297969160558386

# %% [markdown]
# # IBIO

# %%
path = "./Data/IBIO2021.csv"
# Load data, with yesterday close price.
train_x0, train_y0, test_x0, test_y0 = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
train_x0 = np.resize(train_x0, (training_count - history_size, history_size))
test_x0 = np.resize(test_x0, (count - training_count, history_size))
train_x1 = np.hstack((train_x0, train_x0))
test_x1 = np.hstack((test_x0, test_x0))
print(train_x1.shape)
print(test_x1.shape)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (90, 60, 1)
# (30, 60, 1)
# (90, 120)
# (30, 120)

# %%
path = "./Data/IBIO2021.csv"
date = datetime.datetime(2021,3,13)
# Load data, with today close price as ground truth.
_, train_y, _, test_y = utils.get_train_and_test_set(
    path, date, count, history_size, training_count
)
# Out:
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (1243, 8)
# (180, 8)
# (90, 60, 1)
# (30, 60, 1)

# %%
nn_params = [3, 5, 10, 20, 25]
regressor, best_err = knn.knn_model_selection(train_x1, train_y, nn_params)
# Out:
# 3 mean val RMSE: 0.05329823890152434
# Time lapsed 9.596109390258789
# 5 mean val RMSE: 0.05382129531232353
# Time lapsed 8.734941482543945
# 10 mean val RMSE: 0.05783277716424717
# Time lapsed 9.428024291992188
# 20 mean val RMSE: 0.0671157839544396
# Time lapsed 9.301185607910156
# 25 mean val RMSE: 0.06871521696394345
# Time lapsed 9.853124618530273

# %%
y_hat = regressor.fit(train_x1, train_y).predict(test_x1)
plt.plot(y_hat[:], label="estmated")
plt.plot(test_y[:], label="real")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
print("MAE:  ", utils.mae(y_hat, test_y))
print("RMSE: ", utils.rmse(y_hat, test_y))
# Out:
# MAE:   0.06604477611940296
# RMSE:  0.0839013093883892
