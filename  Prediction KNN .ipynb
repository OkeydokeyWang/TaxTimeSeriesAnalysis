# %%
import pandas as pd
import sys
import time

# Constants for stock identification
SP = 0
SONY = 1
WMT = 2

# %% [markdown]
# # Load Feature 1 euro exchange rate from CSV

# %%
df = pd.read_csv("./independendt projecct/euro_exchange_rate.csv")

# %%
# df 前7行去掉 9.30.2019
df = df.iloc[7:,]

# %%
df.head()
# Out:
#            Data Source in SDW: http://sdw.ecb.europa.eu/quickview.do;jsessionid=397A29BB2F1436B9AB6FAEE7A6C2F6BB?SERIES_KEY=120.EXR.D.E5.EUR.EN00.A&start=03-10-2014&end=10-10-2019&submitOptions.x=0&submitOptions.y=0&trans=N
# 2019-09-30                                            96.9520
# 2019-09-27                                            97.1966
# 2019-09-26                                            97.1416
# 2019-09-25                                            97.3576
# 2019-09-24                                            97.3220

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
# 取出exchange rate值
a=df.iloc[:,0:]
euro_byday=df.iloc[:,0:].values

print(type(df))
print(type(euro_byday))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
# 去除空值
for i in range(len(euro_byday)):
    if (euro_byday[i] == "-"):
        j = i
        while euro_byday[j] == "-":
            j = j - 1
        euro_byday[i] = euro_byday[j]

# %%
euro_byday_float = euro_byday.astype('float')

# %%
euro_byday_float = np.flip(euro_byday_float)
euro_byday_float
# Out:
# array([[98.3161],
#        [98.1501],
#        [98.2508],
#        ...,
#        [97.1416],
#        [97.1966],
#        [96.952 ]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(euro_byday_float)

# %% [markdown]
# # Load Feature 2 dj index from CSV

# %%
df = pd.read_csv("./independendt projecct/Dow jones industrial average.csv")

# %%
df = df.iloc[:-2,]
df.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 1251  2019-09-24  27034.070313  27079.679688  26704.960938  26807.769531
# 1252  2019-09-25  26866.710938  27016.560547  26755.859375  26970.710938
# 1253  2019-09-26  27004.109375  27015.070313  26803.839844  26891.119141
# 1254  2019-09-27  26987.259766  27012.539063  26715.820313  26820.250000
# 1255  2019-09-30  26852.330078  26998.859375  26852.330078  26916.830078
#
#          Adj Close     Volume
# 1251  26807.769531  301750000
# 1252  26970.710938  237220000
# 1253  26891.119141  229180000
# 1254  26820.250000  217780000
# 1255  26916.830078  222680000

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
d = df.values[:,1:-2]

# %%
dj_byday_float = d.astype('float')

# %%
dj_byday_float
# Out:
# array([[16802.199219, 17027.839844, 16802.199219, 17009.689453],
#        [17010.339844, 17099.390625, 16930.380859, 16991.910156],
#        [16988.25    , 16988.25    , 16715.789063, 16719.390625],
#        ...,
#        [27004.109375, 27015.070313, 26803.839844, 26891.119141],
#        [26987.259766, 27012.539063, 26715.820313, 26820.25    ],
#        [26852.330078, 26998.859375, 26852.330078, 26916.830078]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(dj_byday_float)

# %% [markdown]
# # Load Feature 3 CPI.csv

# %%
df = pd.read_csv("./independendt projecct/CPI.csv")

# %%
df = df.iloc[:-2,1:-2]

# %% [markdown]
# ## Process Data

# %%
import numpy as np

# %%
CPI_byday = df.values[:,1:-2]

# %%
CPI_byday_float =CPI_byday.astype('float')

# %%
CPI_byday_float
# Out:
# array([[26.42    ],
#        [26.49    ],
#        [26.5     ],
#        ...,
#        [28.030001],
#        [27.99    ],
#        [27.950001]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(CPI_byday_float)

# %% [markdown]
# # Load Feature 4 GBBEF(exchange coe).csv

# %%
df = pd.read_csv("./independendt projecct/GBBEF(exchange coe).csv")

# %%
df = df.iloc[:-10,]
df.tail()
# Out:
#             Date  Open  High   Low  Close  Adj Close  Volume
# 1244  2019-09-26  31.9  31.9  31.9   31.9       31.9       0
# 1245  2019-09-27  31.9  31.9  31.9   31.9       31.9       0
# 1246  2019-09-30  31.9  31.9  31.9   31.9       31.9       0
# 1247  2019-10-01  31.9  31.9  31.9   31.9       31.9       0
# 1248  2019-10-02  31.9  31.9  31.9   31.9       31.9       0

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
GBBEF_byday = df.values[:,1:-2]

# %%
GBBEF_byday_float =GBBEF_byday.astype('float')

# %%
GBBEF_byday_float
# Out:
# array([[42.299999, 42.299999, 42.299999, 42.299999],
#        [42.299999, 42.299999, 42.299999, 42.299999],
#        [42.299999, 42.299999, 42.299999, 42.299999],
#        ...,
#        [31.9     , 31.9     , 31.9     , 31.9     ],
#        [31.9     , 31.9     , 31.9     , 31.9     ],
#        [31.9     , 31.9     , 31.9     , 31.9     ]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(GBBEF_byday_float)

# %% [markdown]
# # Load Feature 5 Oil Prices

# %%
df = pd.read_csv("./independendt projecct/Crude oil prices.csv")

# %%
# df = df.iloc[:-4,]
df.tail()
# Out:
#             DATE DCOILWTICO
# 1300  2019-09-24      57.22
# 1301  2019-09-25      56.38
# 1302  2019-09-26      56.24
# 1303  2019-09-27      55.95
# 1304  2019-09-30      54.09

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
oil_byday = df.values[:,1:]

# %%
# 去除空值
for i in range(len(oil_byday)):
    if (oil_byday[i] == "."):
        j = i
        while oil_byday[j] == ".":
            j = j - 1
        oil_byday[i] = oil_byday[j]

# %%
oil_byday_float = oil_byday.astype('float')

# %%
oil_byday_float
# Out:
# array([[91.17],
#        [90.74],
#        [91.02],
#        ...,
#        [56.24],
#        [55.95],
#        [54.09]])

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(oil_byday_float)

# %% [markdown]
# # Load Value1 SP500

# %%
df = pd.read_csv("./independendt projecct/SP500.csv")

# %%
df = df.iloc[:,]
df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1254  2019-09-24  3002.429932  3007.979980  2957.729980  2966.600098
# 1255  2019-09-25  2968.350098  2989.820068  2952.860107  2984.870117
# 1256  2019-09-26  2985.729980  2987.280029  2963.709961  2977.620117
# 1257  2019-09-27  2985.469971  2987.310059  2945.530029  2961.790039
# 1258  2019-09-30  2967.070068  2983.850098  2967.070068  2976.739990
#
#         Adj Close      Volume
# 1254  2966.600098  3868160000
# 1255  2984.870117  3318870000
# 1256  2977.620117  3077240000
# 1257  2961.790039  3243650000
# 1258  2976.739990  3247610000

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
SP_byday = df.values[:,-2]

# %%
SP_byday_float = SP_byday.astype('float')

# %%
SP_byday_float = SP_byday_float.T

# %%
SP_byday_float.shape
# Out:
# (1259,)

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(SP_byday_float)

# %% [markdown]
# # Load Value3 Walmart

# %%
df = pd.read_csv("./independendt projecct/WMT.csv")

# %%
df = df.iloc[:-3,]
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1254  2019-09-24  118.250000  119.860001  118.010002  118.400002  117.871300
# 1255  2019-09-25  118.470001  118.720001  117.809998  118.470001  117.940987
# 1256  2019-09-26  118.800003  119.550003  118.190002  118.300003  117.771744
# 1257  2019-09-27  119.209999  119.230003  117.750000  118.449997  117.921074
# 1258  2019-09-30  118.669998  119.440002  118.559998  118.680000  118.150047
#
#        Volume
# 1254  7273100
# 1255  4613600
# 1256  3986900
# 1257  3434700
# 1258  3401400

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
WMT_byday = df.values[:,-2]

# %%
WMT_byday_float = WMT_byday.astype('float')

# %%
WMT_byday_float = WMT_byday_float.T

# %%
WMT_byday_float.shape
# Out:
# (1259,)

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(WMT_byday_float)

# %% [markdown]
# # Load Label from Sony another CSV (close Price)

# %%
df = pd.read_csv("./independendt projecct/SNE.csv")

# %%
df = df.iloc[:-2,]
df.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1251  2019-09-24  59.669998  59.770000  58.720001  58.910000  58.910000
# 1252  2019-09-25  60.400002  60.740002  59.869999  60.580002  60.580002
# 1253  2019-09-26  59.910000  60.080002  59.230000  59.410000  59.410000
# 1254  2019-09-27  58.830002  59.389999  58.650002  58.770000  58.770000
# 1255  2019-09-30  58.490002  59.180000  58.099998  59.130001  59.130001
#
#        Volume
# 1251   987800
# 1252  1522500
# 1253   825500
# 1254  1501700
# 1255   666700

# %%
close_sony_byday = df.values[:,4]
length = close_sony_byday.shape[0]

# %%
close_sony_byday.shape
# Out:
# (1256,)

# %% [markdown]
# # Process Data

# %%
import numpy as np

# %%
# for i in range(len(b)):
#     if (b[i] == "-"):
#         j = i
#         while b[j] == "-":
#             j = j - 1
#         b[i] = b[j]

# %%
close_sony_byday_float = close_sony_byday.astype('float')

# %%
close_sony_byday_float = close_sony_byday_float.T
close_sony_byday_float.shape
# Out:
# (1256,)

# %% [markdown]
# # Visualize

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(close_sony_byday_float*400) # Magnify for comparison
# plt.plot(cpi_byday_float*10000-200000)
# plt.plot(euro_byday_float*500)
plt.show()

# %% [markdown]
# # Fit model

# %%
from sklearn import linear_model
length = 1200

# %%
# Features that will be used
feat1 = np.array(euro_byday_float)
feat2 = np.array(CPI_byday_float)
feat3 = np.array(dj_byday_float)
feat4 = np.array(GBBEF_byday_float)
feat5 = np.array(oil_byday_float)
# Labels
val1 = np.matrix(SP_byday_float).T
val2 = np.matrix(close_sony_byday_float).T
val3 = np.matrix(WMT_byday_float).T

# %%
# unify shape
feat1 = feat1[-length:,:]
feat2 = feat2[-length:,:]
feat3 = feat3[-length:,:]
feat4 = feat4[-length:,:]
feat5 = feat5[-length:,:]

# Add yesterday price as feature
feat6 = val1[-length-1:-1,:] # SP
feat7 = val2[-length-1:-1,:] # Sony
feat8 = val3[-length-1:-1,:] # WMT

val1 = val1[-length:,:]
val2 = val2[-length:,:]
val3 = val3[-length:,:]

sp_yesterdaytoday = (feat6, val1)

sony_yesterdaytoday = (feat7, val2)

wmt_yesterdaytoday = (feat8, val3)

# In this exact order as defined in the first cell
stockinfos =sp_yesterdaytoday,sony_yesterdaytoday,wmt_yesterdaytoday

# %% [markdown]
# ## Build data set

# %%
TO_PREDICT = SP
data = np.hstack((
    feat1,
    feat2,
    feat3, 
    feat4,
    feat5,
    # stock related values
    stockinfos[TO_PREDICT][0],  # Yesterdyay
    stockinfos[TO_PREDICT][1],  # Label (Closing today)
))

# %%
data.shape
# Out:
# (1200, 13)

# %%
data = data.T

# %%
# Split train validation,and test
train_data = data[:,:1000]
test_data = data[:,1000:1050]

# %%
LABEL_COUNT = 1  # Dimension of the label
train_x = train_data[:-LABEL_COUNT,:].T
train_y = train_data[-LABEL_COUNT:,:].T

test_x = test_data[:-LABEL_COUNT,:].T
test_y = test_data[-LABEL_COUNT:,:].T

# %% [markdown]
# ## Linear Regression w/ Cross Validation

# %%
from sklearn.model_selection import KFold
# import sklearn package
from sklearn import neighbors

# %%
# Compute MAE
def compute_error(y_hat, y):
    # mean absolute error
    return np.abs(y_hat - y).mean()

def compute_error_normalized(y_hat, y):
    sum_peaks = [];
    for i in range(len(y)):
        if (i == 0 or y[i-1] < y[i]):
            if (i == len(y)-1 or y[i] > y[i+1]):
                sum_peaks.append(y[i])
                
    return np.abs(y_hat - y).mean() / np.array(sum_peaks).mean()

# %%
N_NEIGHBORS = [3, 5, 10, 20, 25]

# Vars to store results
cval_errs = {}
train_time = {}
best_af_nn_regressor = None
best_err = sys.maxsize

for nn in N_NEIGHBORS:
    kf = KFold(n_splits=5, random_state=None, shuffle=False)
    y_err = []

    start = time.time()

    # Cross Validaiton
    for train_index, val_index in kf.split(train_x):
    #     print("TRAIN:", train_index, "VAL:", val_index)
        X_train, X_val = train_x[train_index], train_x[val_index]
        y_train, y_val = train_y[train_index], train_y[val_index]

        NNRegressor = neighbors.KNeighborsRegressor(n_neighbors=nn)
        y_hat = NNRegressor.fit(X_train, y_train).predict(X_val)
    #     print(y_hat)
        y_err.append(compute_error(y_hat, y_val))

    end = time.time()

    print(str(nn), "mean val MAE:", np.mean(y_err))
    print("Time lapsed", str((end - start)*1000))

    # add to dict
    cval_errs[str(nn)] = np.mean(y_err)
    train_time[str(nn)] = (end - start)*1000
    if np.mean(y_err) < best_err:
        best_af_nn_regressor = neighbors.KNeighborsRegressor(n_neighbors=nn)
        best_af_nn_regressor = best_af_nn_regressor.fit(train_x, train_y)
        best_err = np.mean(y_err)

print(best_af_nn_regressor, best_err)
# Out:
# 3 mean val MAE: 34.07818684899997
# Time lapsed 9.667634963989258
# 5 mean val MAE: 34.81289287920002
# Time lapsed 9.21773910522461
# 10 mean val MAE: 36.8706752252
# Time lapsed 9.536504745483398
# 20 mean val MAE: 40.50192089469997
# Time lapsed 10.222673416137695
# 25 mean val MAE: 41.838297213560004
# Time lapsed 10.349512100219727
# KNeighborsRegressor(n_neighbors=3) 34.07818684899997

# %% [markdown]
# # Test

# %%
best_af_nn_regressor = best_af_nn_regressor.fit(train_x, train_y)

# %%
y_hat = best_af_nn_regressor.predict(test_x)

# %%
plt.plot(y_hat[:], label="estmated SP")
plt.plot(test_y[:], label="real SP")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# # Test Error

# %%
compute_error(y_hat, test_y)
# Out:
# 53.33726730666658

# %%
compute_error_normalized(y_hat, test_y)*100
# Out:
# 2.009334982614483

# %%
#SONY#

# %%
TO_PREDICT = SONY
data = np.hstack((
    feat1,
    feat2,
    feat3, 
    feat4,
    feat5,
    # stock related values
    stockinfos[TO_PREDICT][0],  # Yesterdyay
    stockinfos[TO_PREDICT][1],  # Label (Closing today)
))

# %%
data.shape
# Out:
# (1200, 13)

# %%
data = data.T

# %%
# Split train validation,and test
train_data = data[:,:1000]
test_data = data[:,1000:1050]

# %%
LABEL_COUNT = 1  # Dimension of the label
train_x = train_data[:-LABEL_COUNT,:].T
train_y = train_data[-LABEL_COUNT:,:].T

test_x = test_data[:-LABEL_COUNT,:].T
test_y = test_data[-LABEL_COUNT:,:].T

# %% [markdown]
# ## Linear Regression w/ Cross Validation

# %%
from sklearn.model_selection import KFold
# import sklearn package
from sklearn import neighbors

# %%
# Compute MAE
def compute_error(y_hat, y):
    # mean absolute error
    return np.abs(y_hat - y).mean()

# %%
N_NEIGHBORS = [3, 5, 10, 20, 25]

# Vars to store results
cval_errs = {}
train_time = {}
best_af_nn_regressor = None
best_err = sys.maxsize

for nn in N_NEIGHBORS:
    kf = KFold(n_splits=5, random_state=None, shuffle=False)
    y_err = []

    start = time.time()

    # Cross Validaiton
    for train_index, val_index in kf.split(train_x):
    #     print("TRAIN:", train_index, "VAL:", val_index)
        X_train, X_val = train_x[train_index], train_x[val_index]
        y_train, y_val = train_y[train_index], train_y[val_index]

        NNRegressor = neighbors.KNeighborsRegressor(n_neighbors=nn)
        y_hat = NNRegressor.fit(X_train, y_train).predict(X_val)
    #     print(y_hat)
        y_err.append(compute_error(y_hat, y_val))

    end = time.time()

    print(str(nn), "mean val MAE:", np.mean(y_err))
    print("Time lapsed", str((end - start)*1000))

    # add to dict
    cval_errs[str(nn)] = np.mean(y_err)
    train_time[str(nn)] = (end - start)*1000
    if np.mean(y_err) < best_err:
        best_af_nn_regressor = neighbors.KNeighborsRegressor(n_neighbors=nn)
        best_af_nn_regressor = best_af_nn_regressor.fit(train_x, train_y)
        best_err = np.mean(y_err)

print(best_af_nn_regressor, best_err)
# Out:
# 3 mean val MAE: 3.5456499036666664
# Time lapsed 9.29570198059082
# 5 mean val MAE: 3.491733939000001
# Time lapsed 9.11402702331543
# 10 mean val MAE: 3.372201950200001
# Time lapsed 9.285449981689453
# 20 mean val MAE: 3.4491274223999993
# Time lapsed 9.585142135620117
# 25 mean val MAE: 3.49339113212
# Time lapsed 10.222434997558594
# KNeighborsRegressor(n_neighbors=10) 3.372201950200001

# %% [markdown]
# # Test

# %%
best_af_nn_regressor = best_af_nn_regressor.fit(train_x, train_y)

# %%
y_hat = best_af_nn_regressor.predict(test_x)

# %%
plt.plot(y_hat[:], label="estmated SONY")
plt.plot(test_y[:], label="real SONY")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# # Test Error

# %%
compute_error(y_hat, test_y)
# Out:
# 5.156379671999999

# %%
compute_error_normalized(y_hat, test_y)*100
# Out:
# 10.548862017337637

# %%
print("MAE:  ", mae(y_hat, test_y))
print("RMSE: ", rmse(y_hat, test_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-0fd0588d57f8> in <module>
# ----> 1 print("MAE:  ", mae(y_hat, test_y))
#       2 print("RMSE: ", rmse(y_hat, test_y))
#
# NameError: name 'mae' is not defined

# %%
#WMT#

# %%
TO_PREDICT = WMT
data = np.hstack((
    feat1,
    feat2,
    feat3, 
    feat4,
    feat5,
    # stock related values
    stockinfos[TO_PREDICT][0],  # Yesterdyay
    stockinfos[TO_PREDICT][1],  # Label (Closing today)
))

# %%
data.shape

# %%
data = data.T

# %%
# Split train validation,and test
train_data = data[:,:1000]
test_data = data[:,1000:1050]

# %%
LABEL_COUNT = 1  # Dimension of the label
train_x = train_data[:-LABEL_COUNT,:].T
train_y = train_data[-LABEL_COUNT:,:].T

test_x = test_data[:-LABEL_COUNT,:].T
test_y = test_data[-LABEL_COUNT:,:].T

# %% [markdown]
# ## Linear Regression w/ Cross Validation

# %%
from sklearn.model_selection import KFold
# import sklearn package
from sklearn import neighbors

# %%
# Compute MAE
def compute_error(y_hat, y):
    # mean absolute error
    return np.abs(y_hat - y).mean()

# %%
N_NEIGHBORS = [3, 5, 10, 20, 25]

# Vars to store results
cval_errs = {}
train_time = {}
best_af_nn_regressor = None
best_err = sys.maxsize

for nn in N_NEIGHBORS:
    kf = KFold(n_splits=5, random_state=None, shuffle=False)
    y_err = []

    start = time.time()

    # Cross Validaiton
    for train_index, val_index in kf.split(train_x):
    #     print("TRAIN:", train_index, "VAL:", val_index)
        X_train, X_val = train_x[train_index], train_x[val_index]
        y_train, y_val = train_y[train_index], train_y[val_index]

        NNRegressor = neighbors.KNeighborsRegressor(n_neighbors=nn)
        y_hat = NNRegressor.fit(X_train, y_train).predict(X_val)
    #     print(y_hat)
        y_err.append(compute_error(y_hat, y_val))

    end = time.time()

    print(str(nn), "mean val MAE:", np.mean(y_err))
    print("Time lapsed", str((end - start)*1000))

    # add to dict
    cval_errs[str(nn)] = np.mean(y_err)
    train_time[str(nn)] = (end - start)*1000
    if np.mean(y_err) < best_err:
        best_af_nn_regressor = neighbors.KNeighborsRegressor(n_neighbors=nn)
        best_af_nn_regressor = best_af_nn_regressor.fit(train_x, train_y)
        best_err = np.mean(y_err)

print(best_af_nn_regressor, best_err)

# %% [markdown]
# # Test

# %%
best_af_nn_regressor = best_af_nn_regressor.fit(train_x, train_y)

# %%
y_hat = best_af_nn_regressor.predict(test_x)

# %%
plt.plot(y_hat[:], label="estmated WMT")
plt.plot(test_y[:], label="real WMT")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# # Test Error

# %%
compute_error(y_hat, test_y)

# %%
compute_error_normalized(y_hat, test_y)*100

# %%
print("MAE:  ", mae(y_hat, test_y))
print("RMSE: ", rmse(y_hat, test_y))
